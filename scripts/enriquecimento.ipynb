# %%
import duckdb

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute("SELECT * FROM bronze_z0019").fetchdf()
df.head(10)
# Out:
#    NATBR     MAKTX WERKS MAINS LABST nome_arquivo              data_ingestao
# 0  10001  PARAFUSO  BT10   100   100  z0019_1.csv 2026-04-19 01:50:25.826680
# 1  10002   MARTELO  BT50   100   100  z0019_1.csv 2026-04-19 01:50:25.826680
# 2  10003     PREGO  BT10   100    50  z0019_1.csv 2026-04-19 01:50:25.826680
# 3  10004     SERRA  BT50   100   200  z0019_2.csv 2026-04-19 02:07:09.725428
# 4  10005   MACHADO  BT50   100   100  z0019_2.csv 2026-04-19 02:07:09.725428
# 5  10003     PREGO  BT10   100    60  z0019_2.csv 2026-04-19 02:07:09.725428
# 6  10004     SERRA  BT50   100   200  z0019_2.csv 2026-04-19 02:08:28.224197
# 7  10005   MACHADO  BT50   100   100  z0019_2.csv 2026-04-19 02:08:28.224197
# 8  10003     PREGO  BT10   100    60  z0019_2.csv 2026-04-19 02:08:28.224197
